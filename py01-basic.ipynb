# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(len(keyword.kwlist))
# Out:
# 35

# %%
a = 10
print(dir(a))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes']

# %%
# python version 확인
# !python --version
# Out:
# Python 3.12.13

# %%
# %pwd
# !과 #는 실행하는 커널이 다르다 / %는 주피터 커널에서 실행한것이다.
# Out:
# 'c:\\sk-encore\\py-uv-workspace'

# %%
print(10 , end='')
print(' Hello world')
# Out:
# 10 Hello world

# %%
# 키워드는 식별자로 사용할 수 없다.

# %%
#내장함수는 식별자로 사용할 수 있다 / 그러나 원래의 기능을 잃어버린다
# list함수의 기능을 원상복귀하기 위해서는 del키워드를 이용하면 된다
list = [1, 3, 4, 5]
print(list)

del list

print(list())
# Out:
# [1, 3, 4, 5]
# []

# %%
list[0]
# Out:
# 1

# %%
sum(list)
# Out:
# 13

# %%
start = end = 1
print(start)
print(end)
# Out:
# 1
# 1

# %%
a = '3' + '4'
b = 3 + 4
print(a)  # 문자열 연결의 의미로 사용된 덧셈이다
print(b)  # 산술 연산자의 의미로 사용을 한 것이다.
# Out:
# 34
# 7

# %%
# java, c의 경우에는
# int num = 3

# python, javascript의 경우에는 
num = 10
num = 'python'

num

#2차원을 3차원으로 바꾸고 차원 바꾸는게 어렵다...?
# Out:
# 'python'

# %% [markdown]
# # 자료형
#
#
# 1. 데이터 저장방법에 따른 자료형의 분류
#   직접(direct)형 : 직접 데이터를 표현하는 자료형 : int, float, complex
#   시퀀스(sequence)형: 다른 데이터를 포함하는 자료형, 순서가 있는 집합 자료형 : list,str, tuple, bytes, bytearray,range
#   매핑(Mapping)형 : 다른 데이터를 포함하는 자료형 : dict
#   집합(Set)형 : 순서가 없고, 중복된 값도 없다. : set, frozenset
#
#
# 2. 변경 가능성에 따른 자료형 분류
#   변경 가능형(Mutable) : 데이터의 값을 변경할 수 있다.  : list, dict, set
#   변경 불가능형(Immutable) : 데이터의 값을 변경할 수 없다. : int, float, complex, str, tuple, frozenset
#
#
# 3. 데이터 저장 개수에 따른 자료형의 분류
#   리터널(Literal/Scalar)형 : 한 가지 객체만 저장한다. : int, bytes, str, float, complex
#   컨테이너(Container)형 : 여러 가지 객체를 저장한다. : list, tuple, dict, set, fronzenset

# %% [markdown]
# type(): 데이터 자료형 확인

# %%
type(5)
# Out:
# int

# %%
def call():
    return 2

# %%
type(call)
# Out:
# function

# %% [markdown]
# dir(): 객체의 자원을 검색할 수 있다.

# %%
print(dir(int))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'is_integer', 'numerator', 'real', 'to_bytes']

# %%
a = [1, 2, 3]
print(dir(a))
print(a.__dir__())

# a 객체가 가지고 있는 기능 목록을 출력하는 코드
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# ['__new__', '__repr__', '__hash__', '__getattribute__', '__lt__', '__le__', '__eq__', '__ne__', '__gt__', '__ge__', '__iter__', '__init__', '__len__', '__getitem__', '__setitem__', '__delitem__', '__add__', '__mul__', '__rmul__', '__contains__', '__iadd__', '__imul__', '__reversed__', '__sizeof__', 'clear', 'copy', 'append', 'insert', 'extend', 'pop', 'remove', 'index', 'count', 'reverse', 'sort', '__class_getitem__', '__doc__', '__str__', '__setattr__', '__delattr__', '__reduce_ex__', '__reduce__', '__getstate__', '__subclasshook__', '__init_subclass__', '__format__', '__dir__', '__class__']

# %% [markdown]
# help(): 자료형에서 제공하는 메서드 사용법을 검색할 수 있다

# %%
# print(help(str))
print(help(str.index))
# Out:
# Help on method_descriptor:
#
# index(...) unbound builtins.str method
#     S.index(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Raises ValueError when the substring is not found.
#
# None

# %%
'hello'.index('e')
# Out:
# 1

# %% [markdown]
# ## Sequence 자료형
# - Sequence은 여러 객체를 저장할 수 있는 순서를 갖는 연속된 자료형이다.
# - 자료형 종류 : str, tuple, list
# - sequence형의 공통적인 연산
#   - 인덱싱(indexing) - 선택연산
#   - 슬라이싱(slicing) - 범위선택연산
#   - 연결하기
#   - 반복하기
#   - 멤버 검사
#   - 길이정보

# %% [markdown]
# 문자열(str)
#
#
# 문자열은 문자들을 표현하는 자료형으로 작은따옴표(')나 큰따옴표(")로 묶는다.
# 문자열의 슬라이싱 : [인덱스 시작 : 인덱스 끝 미만: 스텝]
# 스텝의 default은 1의 값을 갖는다.

# %%
a = 'Life is short, You need Python'
print(a)

a = "Life is short, You need Python"
print(a)
# Out:
# Life is short, You need Python
# Life is short, You need Python

# %%
a = ''Python's'
# Out:
#   Cell In[58], line 1
#     a = ''Python's'
#           ^
# SyntaxError: invalid syntax

# %%
a = 'Python\'s'  # \를 쓰면 문자열로 사용이 된 것이다. #\'
print(a)
# Out:
# Python's

# %%
a = "\"Python\'s favorite food is perl\""   #\"
print(a)
# Out:
# "Python's favorite food is perl"

# %%
b = """
     Life goes on
"""

print(b)
# Out:
#      Life goes on

# %%
# 문자열 길이
print(len(b))
# Out:
# 19

# %%
# 인덱싱
s_val = 'hello python'
print(s_val[1])
# Out:
# e

# %%
# 슬라이싱 / [start:end] / :(콜론)은 절대 생략 금지 / step은 생략가능, step의 default = 1
print(s_val[1:5])
# Out:
# ello

# %%
print(s_val[0:]) # 0부터 끝까지
print(s_val[:])
# Out:
# hello python
# hello python

# %%
print(s_val[-1:-3:-1]) # 역순으로 하고 싶으면 -1을 step값을 줘야 한다
# Out:
# no

# %%
# 타입이 다른 것끼리 곱하는 것은 가능하다 / 문자열 반복하기 연산
s_val * 2
# Out:
# 'hello pythonhello python'

# %% [markdown]
# 문자열을 변경할 때 슬라이싱과 연결하기 쉬움

# %%
s_val = 'hello Phython'
s_val = 'H'+s_val[1:]
print(s_val)
# Out:
# Hello Phython

# %%
s_val = 'red green blue'
print(s_val)
# Out:
# red green blue

# %%
# s_val 변수에 green이 있니?
'green' in s_val
# Out:
# True

# %%
'white' in s_val
# Out:
# False

# %% [markdown]
# 문자열 포매팅(서식지정) : 어떤 문서 양식을 만들어 넣고 빈칸에 필요한 내용을 채워서 문서를 지정한다.
#
#
# 문자열포매팅(서식지정) 형식
#
#
# |코드|설명 |
# |---|:---:|
# |%d|정수|
# |%f|실수|
# |%s|문자열|
# |%c|하나의문자|
# |%o|8진수|
# |%x|16진수|
# |%%|%기호자체를출력하고자할때|

# %%
s_val7 = 'python'
s_val8 = 83.5


print('%s 의 점수는 %.1f입니다.' % ( s_val7, s_val8)) # python1, 2방식
print('{} 의 점수는 {}입니다.'.format(s_val7, s_val8)) # python3 방식
print('{1} 의 점수는 {0}입니다.'.format(s_val8, s_val7))
print('{subject} 의 점수는 {jumsu}입니다.'.format(jumsu=s_val8, subject=s_val7))
print('{{0}} 의 점수는 {{1}}입니다.'.format(s_val7, s_val8)) # { }자체를 출력할
때 {{}}을 한다.
print('{{{0}}} 의 점수는 {{{1}}}입니다.'.format(s_val7, s_val8)) # {}자체와 값을 출력할때는 {{{}}}을 한다.


print('{0:<10} 의 점수는 {1}입니다.'.format(s_val7, s_val8))  # 10자리 확보하고 남은 공간은 오른쪽을 여백으로 채운다.
#print('{:<10} 의 점수는 {}입니다.'.format(s_val7, s_val8))


print('{0:>10} 의 점수는 {1}입니다.'.format(s_val7, s_val8))
# Out:
# python 의 점수는 83.5입니다.
# python 의 점수는 83.5입니다.
# python 의 점수는 83.5입니다.
# python 의 점수는 83.5입니다.
# {0} 의 점수는 {1}입니다.
# {python} 의 점수는 {83.5}입니다.
# python     의 점수는 83.5입니다.
#     python 의 점수는 83.5입니다.

# %% [markdown]
# 문자열에서 제공하는 메소드

# %%
a = 'hobby'
print(a.count('b'))  # b의 문자 개수 리턴
# Out:
# 2

# %%
print(a.find('b'))
print(a.index('b'))
# Out:
# 2
# 2

# %%
print(a.find('c'))  # 찾는 문자열이 없으면 -1을 리턴한다
print(a.index('c'))   # 찾는 문자열이 없으면 오류 발생한다.
# Out:
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 2
#       1 print(a.find('c'))  # 찾는 문자열이 없으면 -1을 리턴한다
# ----> 2 print(a.index('c'))   # 찾는 문자열이 없으면 오류 발생한다.
#
# ValueError: substring not found

# %%
# 'apple' 문자열의 각각의 문자 사이에 '*'을 삽입한다.
'*'.join('apple')
# Out:
# 'a*p*p*l*e'

# %%
'*'.join(['red','green','blue'])
# Out:
# 'red*green*blue'

# %%
a = 'hello'
print(a.upper())
# Out:
# HELLO

# %%
a = ' hello world '
print(len(a))

print(a.lstrip())
print(len(a.strip()))
# Out:
# 13
# hello world
# 11

# %%
a = 'Hello Python'
print(a.replace('Python', '파이썬'))
print(a)
# Out:
# Hello 파이썬
# Hello Python

# %%
a = 'Red Green Blue'
print(a.split()) # 공백으로 분리가 된다

a = 'Red*Green*Blue'
print(a.split('*'))
# Out:
# ['Red', 'Green', 'Blue']
# ['Red', 'Green', 'Blue']

# %%
import re
a = 'Red**Green*Blue'
print(re.split(r'\*+',a))

# 이것 좀 헷갈린다??//
# Out:
# ['Red', 'Green', 'Blue']

# %% [markdown]
# 리스트(list)
# - 시퀀스(sequence)자료형으로  데이터의 크기나 원소값을 변경할 수 있다.
# - 리스트는 []대괄호로 표현한다.

# %%
a = list()
print(a)
print(type(a))
print(dir(a))
# Out:
# []
# <class 'list'>
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %% [markdown]
# list는 다양한 타입을 함께 포함할 수 있다.(hetergeneous)

# %% [markdown]
# list는(+)연산자를 사용하여 연결하기를 할 수 있다.

# %%
a = 'spiderman'
b = a[0:6] + 'woman'
print(b)
print(a)
# Out:
# spiderwoman
# spiderman

# %% [markdown]
# list에서 확장슬라이싱을 할때는 왼쪽과 오른쪽 요소 갯수가 같아야 한다.

# %%
a = [2, 4, 6, 8]
print(a)

a[:] = [-1, -2, -3, -4]
print(a)


# 갯수 안맞으면 오류가 뜬다.
a[:] = [-1, -2, -3, -4, -5]
print(a)

a = [2, 4, 6, 8]
print(a)

a[:] = [-1, -2, -3, -4]
print(a)
# Out:
# [2, 4, 6, 8]
# [-1, -2, -3, -4]
# [-1, -2, -3, -4, -5]
# [2, 4, 6, 8]
# [-1, -2, -3, -4]

# %% [markdown]
# list는 한 변수에서 데이터를 각각 각각 꺼내는 언팩킹(unpacking) 지원을 한다.

# %%
fruits = ['apple', 'mango', 'grape', 'orange']
print(fruits)

zero, one, two, three = fruits
print(zero, one, two, three)

zero, *group = fruits    #group화는 한번만 사용이 가능하다.
print(zero, group)


*group, zero,= fruits    # 반대로 하는 것도 가능하다. 단지 그 밖에 *두개를 사용한 *group1, *group2는 이렇게 중복사용이 안된다.
print(zero, group)
# Out:
# ['apple', 'mango', 'grape', 'orange']
# apple mango grape orange
# apple ['mango', 'grape', 'orange']
# orange ['apple', 'mango', 'grape']

# %% [markdown]
# 튜플(Tuple)
# - 변경이 불가능한(imutable)한 순서(sequence)가 있는 자료형이다.
# - 튜플은 ()소괄호를 사용한다.

# %%
t = 1,2,3 # tuple은 () 소괄호를 생략할 수 있다.
print(t, type(t))
# Out:
# (1, 2, 3) <class 'tuple'>

# %%
t = (2)
print(t, type(t))
# Out:
# 2 <class 'int'>

# %%
t = (2,)   # (없으면 int로 인식하는데 있으면 있으면 튜플로 인식한다.)
print(t, type(t))
# Out:
# (2,) <class 'tuple'>

# %%
a = [3,1,5,2,5]
b = set(a)

# 1. 집합은 중복을 허용하지 않는다
# 2. set()을 사용할 때 중복을 제거하고 집합으로 변환해주는 데 밑의 결과가 그렇게 나오는건 저장형식 때문에 오름차순으로 나오는거다

print(b)
# Out:
# {1, 2, 3, 5}
