# %% [markdown]
# ## 함수(function)
#  - 함수: 특정 목적을 가진 코드의 집합이며 독립적으로 호출될 수 있는 기능이다.
#  - 함수 구조
#   ```
#     def 함수이름(parameter_1, parameter_2) :
#         수행할 문장
#         return 결과값
#   ```
#  - 함수 호출
#   ```
#      함수이름(argument_1, argument_2 )
#   ```

# %% [markdown]
# parameter: 인자, argument: 인수

# %%
# 함수를 정의할 때 수행할 문장을 구현하지 않으면 에러가 발생한다.
def proc():
  pass  # pass는 구현을 안할때 오류가 발생하지 않도록 사용한다.

# %%
print(proc())  # 함수 실행결과를 리턴한다.
# Out:
# None

# %%
proc() # 넘겨주는 값이 없어서 출력되는 게 없다.

# %%
print(proc) 
# 이렇게 하면 함수 식이 나온다.. 괄호를 붙이지 않으면 그냥 함수식이다.
# 변수의 값으로 함수를 할당할 때 사용한다.
# Out:
# <function proc at 0x000002088F0E9BC0>

# %%
a = proc
print(type(a))
print(a())
print(a.__name__)  # a에 지정된 함수명을 확인할 때 사용한다.
# Out:
# <class 'function'>
# None
# proc

# %% [markdown]
# ## callable
#  - 이름 뒤에( )를 붙이는 것을 call(호출)이라고 한다.
#  - 이름 뒤에( )를 붙일 수 있는 것을 callable이라고 한다.
#  - 함수는 사용할 때 이름 뒤에 괄호를 붙인다.
#  - python에서 callable인 것은 3가지 유형이 있다.
#    - (1)function
#    - (2)class(init가 정의되었을 경우)
#    - (3)object(call이 정의되었을 경우)

# %%
K = 1
K()  # 'int' object is not callable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 K = 1
# ----> 2 K()  # 'int' object is not callable
#
# TypeError: 'int' object is not callable

# %%
callable(K)
# Out:
# False

# %%
callable(proc)
# Out:
# True

# %%
print(__builtins__)
# Out:
# <module 'builtins' (built-in)>

# %%
import builtins
print(dir(builtins))
print(len(dir(builtins)))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemError', 'SystemExit', 'TabError', 'TimeoutError', 'True', 'TypeError', 'UnboundLocalError', 'UnicodeDecodeError', 'UnicodeEncodeError', 'UnicodeError', 'UnicodeTranslateError', 'UnicodeWarning', 'UserWarning', 'ValueError', 'Warning', 'WindowsError', 'ZeroDivisionError', '__IPYTHON__', '__build_class__', '__debug__', '__doc__', '__import__', '__loader__', '__name__', '__package__', '__spec__', 'abs', 'aiter', 'all', 'anext', 'any', 'ascii', 'bin', 'bool', 'breakpoint', 'bytearray', 'bytes', 'callable', 'chr', 'classmethod', 'compile', 'complex', 'copyright', 'credits', 'delattr', 'dict', 'dir', 'display', 'divmod', 'enumerate', 'eval', 'exec', 'execfile', 'filter', 'float', 'format', 'frozenset', 'get_ipython', 'getattr', 'globals', 'hasattr', 'hash', 'help', 'hex', 'id', 'input', 'int', 'isinstance', 'issubclass', 'iter', 'len', 'license', 'list', 'locals', 'map', 'max', 'memoryview', 'min', 'next', 'object', 'oct', 'open', 'ord', 'pow', 'print', 'property', 'range', 'repr', 'reversed', 'round', 'runfile', 'set', 'setattr', 'slice', 'sorted', 'staticmethod', 'str', 'sum', 'super', 'tuple', 'type', 'vars', 'zip']
# 161

# %%
list()
# Out:
# []

# %%
list = 3
print(list)
# Out:
# 3

# %%
list() # 앞에서 list를 식별자로 써버렸기 때문에 표준함수의 기능을 잃어버리니다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 list()
#
# TypeError: 'int' object is not callable

# %%
del list  # list의 원래기능을 찾는 코드다.

# %%
list()
# Out:
# []

# %%
# 파라미터는 없으나 리턴값은 있는 함수
def prn():
    return 1

prn()
# Out:
# 1

# %%
callable(prn)
# Out:
# True

# %%
print(prn())  #   => print(1)
# Out:
# 1

# %%
# 파라미터와 리턴값이 있는 함수 정의
def max(x, y):
    if x >= y:
        res = x
    else:
        res = y
    return res      # 함수에선 리턴은 한번만 사용이 되어야 한다.

# %%
max(4,5)
# Out:
# 5

# %%
def max(x, y):
    if x >= y:
        return x
    else:
        return y

# %%
# 파라미터와 리턴값이 없는 함수 정의
def max():
    x = 10
    y = 5
    if x >= y:
        print(x)
    else: 
        print(y)

# %%
max()
# Out:
# 10

# %%
print(max())  # none이라고 나오면 그냥 리턴이 없는 함수라고 생각하면 된다. # max()의 함수가 먼저 실행이 되어서 10을 출력하고 그 다음 비어있는 괄호를 print()하게 되기 때문이다.
# Out:
# 10
# None

# %% [markdown]
# ## paramter와 argument
# 1. positional
# 2. keyword
# 3. positional & keyword
# 4. positional only
# 5. keyword only
# 6. 가변 positional
# 7. 가변 keyword

# %% [markdown]
# 1. positional
#  - 함수 호출 : 선언할 때 파라미터의 순서와 호출할때 argument의 입력순서를 그대로 매칭한다.

# %%
def proc(a, b):
    return a, b

# 모든 함수는 무조건 return 되는 것이 하나이다. / 넘겨준 기호는 튜플로 기호가 생략되어있다. / 주의하자!!

# %%
proc(2,3)
# Out:
# (2, 3)

# %%
def prec(a,b):
    return [3,4]

prec(3,4)
# Out:
# [3, 4]

# %% [markdown]
# 2. keyword
# - keyword 방식을 이용하면 순서와 상관없이 parameter 이름에 따라 값이 대입된다.

# %%
print(proc(b=4, a=3))
# Out:
# (3, 4)

# %% [markdown]
# 3. keyword & positional 혼합

# %%
def proc(a,b,c):
    return a, b, c

print(proc(2, c=5, b=3))  # 키워드 형태로 호출하면 뒤에도 다 키워드로 써야한다.
# Out:
# (2, 3, 5)

# %%
print(2,b=3,4)  # SyntaxError: positional argument follows keyword argument
# Out:
#   Cell In[57], line 1
#     print(2,b=3,4)  # SyntaxError: positional argument follows keyword argument
#                  ^
# SyntaxError: positional argument follows keyword argument

# %%
# python 버전 확인
! python --version
# Out:
# Python 3.12.13

# %% [markdown]
# 4. positional only
# - positional only는 함수를 사용할 때 positional방식으로만 parameter를 쓸 수 있도록 강제하는 방법이다.
# - / 의 앞에 오는 parameter들은 positional방식으로 입력할 수 있지만,  keyword방식으로 입력할 수 없다.
# - positional only 함수를 정의할 수 있는 것은 python 3.8부터 지원한다. 이전 버전에서는 사전 정의된 positional only 함수는 있지만, 사용자가 만들 수는 없었다.

# %%
def proc(a,b,c,/):
    return a, b, c

# %%
print(proc(4,5,6))
# Out:
# (4, 5, 6)

# %%
print(proc(3,4)) # 개수가 맞지 않으면 안된다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 print(proc(3,4))
#
# TypeError: proc() missing 1 required positional argument: 'c'

# %%
print(proc(4, c=6, b=5))  # 이건 positional only인데 keyword 인자를 써서 문제가 되는 것이다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 print(proc(4, c=6, b=5))
#
# TypeError: proc() got some positional-only arguments passed as keyword arguments: 'b, c'

# %%
def proc(a,b,/,c,d):     # a,b는 무조건 position 근데 뒤에는 뭘 해도 상관없다
    return a, b, c, d

# %%
print(proc(4,5,6,7))
# Out:
# (4, 5, 6, 7)

# %%
print(proc(4, 5, d=7, c=6))
# Out:
# (4, 5, 6, 7)

# %% [markdown]
# 5. keyword only
# - keyword only방식은 keyword방식으로만 입력하도록 강제하는 방법이다.
# - '*' 이후로는 keyword 방식만 가능하다.

# %%
def proc(*, a,b,c,d):
    return a,b,c,d

# %%
print(proc(a=3, c=5, b=4, d=6))
# Out:
# (3, 4, 5, 6)

# %%
print(proc(3,4, d=5, c=5)) # TypeError: proc() takes 0 positional arguments but 2 positional arguments / 이건 keyword only이기 때문이다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 print(proc(3,4, d=5, c=5))
#
# TypeError: proc() takes 0 positional arguments but 2 positional arguments (and 2 keyword-only arguments) were given

# %%
# a,b는 positional 또는 keyword로 사용해도 상관없지만, c,d는 keyword만 가능하다.
def proc(a,b,*,c,d):
    return a,b,c,d

# %%
proc(3,4,d=5,c=3)
# Out:
# (3, 4, 3, 5)

# %%
proc(a=3,b=5,6,7)   # * 과 / 가 서로 무조건 써야하는 위치가 조금 다른 것 같다.
# Out:
#   Cell In[74], line 1
#     proc(a=3,b=5,6,7)
#                     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# 6. 가변 positional
# - 가변 positional은 parameter 이름에 '*'를 붙인다.
# - positional 방식으로 입력되는 argument의 갯수에 상관없이 모두 받아온다.

# %%
def proc(*a):        # 리턴 값은 튜플이다.
    print(type(a))
    return(a)

# %%
print(proc())
# Out:
# <class 'tuple'>
# ()

# %%
print(proc(1, 2, 3))
# Out:
# <class 'tuple'>
# (1, 2, 3)

# %%
print(proc(3,a=5)  # 이건 문법적인 오류로 애초에 a 인자를 정의 안해서 그렇다.
# Out:
#   Cell In[78], line 1
#     print(proc(3,a=5)
#                      ^
# SyntaxError: incomplete input

# %%
def proc(a,*b):
    print(type(a))
    print(type(b))
    return(a,b)

# %%
print(proc(1,2,3,4,5))
# Out:
# <class 'int'>
# <class 'tuple'>
# (1, (2, 3, 4, 5))

# %%
def proc(*a,b):
    print(type(a))
    print(type(b))
    return(a,b)

# %%
print(proc(1,2,3,4,5))  # 보통 가변인자를 뒤로 두는 것이 원칙이다. / 일반 매개변수 뒤에 가변 매개변수를 써야 하는 것이다.
                        # 가변 매개변수는 한번만 사용한다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 print(proc(1,2,3,4,5))
#
# TypeError: proc() missing 1 required keyword-only argument: 'b'

# %% [markdown]
# 7. 가변 keyword
# - 가변 keyword는 parameter 이름에 '**'를 붙인다.
# - keyword방식으로 입력되는 argument의 개수에 상관없이 모두 받아온다.

# %%
def proc(**a):            # dic 형태로 저장이 된다.
    print(type(a))
    return(a)

# %%
proc(x=2, y=3)
# Out:
# <class 'dict'>
# {'x': 2, 'y': 3}

# %%
proc(x=3, y=2, z=[1,2,3])
# Out:
# <class 'dict'>
# {'x': 3, 'y': 2, 'z': [1, 2, 3]}

# %%
proc(3,4,5)  # 무조건 keyword 입력방식으로 입력을 해야 하고 저장할 때는 dic 형태로 저장이 된다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 proc(3,4,5)
#
# TypeError: proc() takes 0 positional arguments but 3 were given

# %% [markdown]
# 가변 positional 과 가변 keyword은 한 번만 사용할 수 있다.

# %%
def proc(*a,**b):
    return a, b

print(proc(1,2,c=3,d=4))       # 1,2는 튜플로 저장이 되고, 3,4는 딕셔너리로 저장이된다.
# Out:
# ((1, 2), {'c': 3, 'd': 4})

# %%
def proc(/, b, c, *)  # 매개변수 제일 앞에 /가 올 수 없고, 제일 뒤에 *이 올 수 없다.  + (* 뒤에는 /을 쓸 수 없다)
    return a, b
print(3,4)
# Out:
#   Cell In[93], line 1
#     def proc(/, b, c, *)
#              ^
# SyntaxError: at least one argument must precede /

# %% [markdown]
# ## return
#   - return의 정의
#      - 함수 내부의 실행을 종료하고, 호출한 곳으로 결과값을 전달하는 키워드
#   - return의 핵심 역할 2가지
#     - 값 반환: 함수에서 계산되거나 처리된 데이터(결과물)를 외부로 내보냄
#     - 함수 종료: return문이 실행되는 즉시 뒤에 코드가 더 있더라도 함수가 끝남
#   - 아무것도 리턴하지  않으면 None을 출력함.  None은 아무것도 없다는 의미임.
#   - 함수에서 return을 2번 이상 사용할 수 없다.
#   - 함수의 결과를 2개 이상으로 받고 싶다면 unpacking해서 받는다.

# %%
def proc(a):
    print(a)
    return        # 함수 중간에 강제적으로 빠져나올때 return 쓴다

# %%
print(proc(3))
# Out:
# 3
# None

# %%
# proc() 함수에서 합계와 평균을 구해서 리턴하는 프로그램을 구현

def proc(*a):  # 자료형 튜플로 받는다
    total = 0
    avg = 0

    total = sum(a)
    avg = total / len(a)        # 근데 일단 코딩을 생각하면 입력되는 개수가 다른데... / a라는 변수자체가 튜플이니까..
                                # *는 튜플이고, **는 딕셔너리로 저장을 한다.
    return (total, avg)

proc(1,2,3)
# Out:
# (6, 2.0)

# %%
proc(3,5,6,3)
# Out:
# (17, 4.25)

# %%
def proc2(*a):
    total = 0
    avg = 0

    for v in a:
        total = total + v

    avg = total / len(a)

    return total, avg

proc2(5,6,7)
# Out:
# (18, 6.0)

# %%
total, avg = proc(1,2,3,4)   # 언패킹 개념이다.
print(f'합계: {total}')
print(f'평균: {avg}')
# Out:
# 합계: 10
# 평균: 2.5

# %% [markdown]
# python은 외부에서 함수 내부의 자원을 직접 접근할 수 없다.

# %%
def proc():
    z = 1

z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 4
#       1 def proc():
#       2     z = 1
#       3
# ----> 4 z
#
# NameError: name 'z' is not defined

# %% [markdown]
# 외부에서 함수 내부의 자원을 접근하기 위해서 return을 사용한다.

# %%
def proc():
    z = 1
    return z

# %%
z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 z
#
# NameError: name 'z' is not defined

# %%
print(proc())
# Out:
# 1

# %% [markdown]
# 함수 내부에서 외부에 접근할 수 있다.

# %%
c = 10 # 전역변수
def proc():
    print(c)

# %%
proc()
# Out:
# 10

# %%
c = 11
def proc():
    c = c + 1
    print(c)

# %%
proc()  # 함수 밖에서 정의된 변수에 대해서 접근은 되지만 변경하는 것은 안된다.
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 proc()  # 함수 밖에서 정의된 변수에 대해서 접근은 되지만 변경하는 것은 안된다.
#
# Cell In[111], line 3, in proc()
#       2 def proc():
# ----> 3     c = c + 1
#       4     print(c)
#
# UnboundLocalError: cannot access local variable 'c' where it is not associated with a value

# %% [markdown]
# global은 내부와 외부의 객체를 동기화(sync)시켜준다.
# global은 사용하기는 편하지만 언제 바뀌었는지 흐름을 파악하기 힘들기 때문에 남용은 하지 않는다.

# %%
c = 3
def proc():
    global c   # 외부 변수 값을 변경하기 전에 global로 선언을 먼저 해준다.
    c = c + 1
    print(c)

# %%
proc()
# Out:
# 4

# %%
c = [1, 2, 3]
def proc():
    c = [4, 5, 6]
    c[0] = 50
    print(c)
proc()
# Out:
# [50, 5, 6]

# %% [markdown]
# 외부 함수의 자원을 내부 함수에서 참조는 가능하지만 변경은 불가능하다
# 변경할 때는 nonlocal을 사용한다.

# %%
k = 1
def outer():
    m = 1
    def inner():
        global k 
        k = k + 1
        
        nonlocal m
        m = m + 1     
        return k, m
    
    return inner()

# %%
outer()
# Out:
# (2, 2)

# %% [markdown]
# ## lambda
# - python에서는 익명함수를 정의할 때 lambda키워드를 사용한다.
# - 간결하게 함수를 표현하거나 def로 정의할 수 없는 경우에 사용한다.
# - 형식
#   함수이름 = lambda 매개변수1, 매개변수 2,... : 매개변수를 이용한 표현식

# %%
add = lambda a, b : a + b

# %%
type(add)
# Out:
# function

# %%
add(1,3)  # lambda 함수가 일회성이 아니라 저장이 되어있긴 하구나!
# Out:
# 4

# %%
add.__name__
# Out:
# '<lambda>'

# %% [markdown]
# 함수를 매개변수로 사용하는 내장(표준)함수: map(), filter()

# %% [markdown]
# map() 함수와의 조합
# - 리스트의 모든 요소를 하나씩 꺼내어 람다 함수로 가공할 때 가장 많이 사용
# - map(함수, 리스트)

# %%
numbers = [1,2,3,4,5]
list(map(lambda x:x**2, numbers))
# Out:
# [1, 4, 9, 16, 25]

# %%
print(map(lambda x:x**2, numbers))
# Out:
# <map object at 0x000002088F1369B0>

# %%
numbers = [1,2,3,4,5]
tuple(map(lambda x:x**2, numbers))
# Out:
# (1, 4, 9, 16, 25)

# %% [markdown]
# filter() 함수와의 조합
#   - 리스트의 요소 중 람다 함수의 조건식이 참(True)인 요소만 걸러낼 때 사용

# %%
numbers = [1,2,3,4,5]

proc_filter = list(filter(lambda x: x%2==0, numbers))
print(proc_filter)
# Out:
# [2, 4]

# %% [markdown]
# sorted() 정렬 기준(key) 지정
# -데이터 정렬 시 key 옵션 활용
#   - 딕셔너리나 튜플로 이루어진 복잡한 리스트를 정렬할 때 기준점을 지정

# %%
students = [('Kim', 85), ('Lee', 92), ('Park', 78)]

proc_sorted = sorted(students, key=lambda x : x[1])  # 점수를 기준으로 오름차순 정렬이다. 기본이 오름차순 청렬이다.
print(proc_sorted)
# Out:
# [('Park', 78), ('Kim', 85), ('Lee', 92)]

# %% [markdown]
# ## 재귀함수
#
#
# ```
# 재귀함수란?
#   - 함수 내부에서 자기 자신을 다시 호출하는 구조를 가진 함수
#   - 복잡한 문제를 더 작은 단위의 동일한 문제로 나누어 해결할 때 유용 (분할정복)
#
#
#  재귀함수의 필수 2대 요소
#   - 1. 기저 조건 (Base Case): 재귀 호출을 멈추고 탈출하는 조건 (구현 누락 시 무한 루프)
#   - 2. 재귀 단계 (Recursive Case): 문제를 작게 쪼개어 자기 자신을 다시 호출하는 부분
#
#
#  기본 개념 구조
#    def proc(n):
#         if n <= 1:                    # 1. 기저 조건
#                return 1
#         return n + proc(n-1)     # 2. 재귀 단계 (자기 자신 호출)

# %% [markdown]
# ### 팩토리얼 (n!) 구현
#   - n부터 1까지의 모든 양의 정수를 곱하는 연산 (n! = n * (n-1) * (n-2) * ... * 1)

# %%
# 재귀함수로 팩토리얼 구하기
def proc_functional(n):
    if n <= 1:   # 기저 단계
        return 1
    return n * proc_functional(n-1)   # 스택이라는 것이 쌓이는 느낌이다. 입출력이 하나다. 한쪽으로만 입력되고 한쪽으로만 출력이 된다.

proc_functional(5)
# Out:
# 120

# %% [markdown]
# ### 재귀함수의 치명적인 문제점 3가지
# 1. 메모리 스택 오버플로우 (Stack Overflow)
#   - 함수가 호출될 때마다 메모리의 '스택(Stack)' 영역에 돌아갈 주소와 지역 변수가 쌓임
#   - 재귀 호출이 깊어지면 스택 메모리 한도를 초과하여 프로그램이 강제 종료됨
#
#
# 2. 막대한 가독성 및 디버깅 비용
#   - 실행 흐름이 직관적이지 않고 복잡하게 얽혀 있어 코드 가독성이 떨어짐
#   - 에러 발생 시 추적(Traceback) 과정이 너무 길어져 디버깅(오류 수정)이 까다로움
#
#
# 3. 심각한 중복 연산과 속도 저하
#   - 이전에 계산했던 값을 기억하지 못하고 똑같은 연산을 무수히 반복함
#   - 숫자가 조금만 커져도 연산량이 기하급수적으로 늘어나 시스템이 멈출 수 있음

# %% [markdown]
# ### 파이썬(Python) 환경에서의 구체적인 한계
#
#
# ① 파이썬 최대 재귀 깊이 제한 (RecursionError)
#   - 파이썬은 스택 오버플로우로 인한 시스템 붕괴를 막는 자체 안전장치가 있음
#   - 기본 제한 횟수: 약 1,000회 (이상을 넘어가면 RecursionError 발생)
#
#
# ② 예제 상황 (함수명: proc_factorial)
#   - proc_factorial(2000) 호출 시 → 시스템이 버티지 못하고 에러를 뿜으며 멈춤
#
#
# ③꼬리 재귀 최적화(Tail Call Optimization) 미지원
#   - 다른 언어(C, Kotlin 등)와 달리 파이썬은 구조적으로 재귀 최적화를 지원하지 않음
#   - 즉, 파이썬에서는 대규모 데이터를 다룰 때 재귀함수 사용을 반드시 지양해야 함

# %% [markdown]
# ### 재귀함수 문제점 해결을 위한 3대 대안
#
#
# ①대안: 반복문(Iteration) 전환
#   - for문이나 while문을 사용하면 스택 메모리를 전혀 쓰지 않아 가장 안전하고 빠름
#
#
# ②대안: 메모이제이션(Memoization) 적용
#   - 한 번 계산한 결과를 딕셔너리 등에 캐싱(저장)하여 중복 연산 수치를 제로로 만듦
#
#
# ③대안: 동적 계획법(Dynamic Programming) 활용
#   - 큰 문제를 작은 하위 문제로 나누되, 아래에서부터(Bottom-up) 상향식으로 채워나감
#
# #### 그래서 알고리즘을 해야한다. 너무 빡세니까   /   뭔지는 대충 아는 것이 좋다

# %%
# 반복문으로 팩토리얼 구하기
def proc_factorial(n):
      result = 1
      # 1부터 n까지 순차적으로 곱하기 진행
      for i in range(1, n + 1):
          result *= i
      return result

print(proc_factorial(5))
# Out:
# 120

# %% [markdown]
# ### 메모이제이션(Memoization)의 개념과 특징 (면접용)
# ```
# ①메모이제이션(Memoization) 기술이란?
#   - 컴퓨터 프로그램이 동일한 계산을 반복해야 할 때, 이전에 계산한 값을
#     메모리에 저장(캐싱)함으로써 동일한 중복 연산을 제거하는 최적화 기법입니다.
#
#
# ② 핵심 작동 원리 2가지
#   - 결과 값 캐싱: 한 번 계산한 결과는 딕셔너리(Dictionary) 등의 메모리 공간에 기록
#   - 재귀 호출 스킵: 이미 계산된 값이 필요할 때는 재귀를 수행하지 않고 즉시 꺼내어 재사용
#
#
# ③ 도입 시 기대 효과
#   - 무수히 반복되는 중복 연산 수치를 제로(0)에 가깝게 만듦
#   - 시간 복잡도를 혁신적으로 줄여 프로그램의 실행 속도를 기하급수적으로 향상시킴

# %%
# 계산된 결과를 저장할 메모리 공간(딕셔너리) 초기화
memo = {}  # 기존에 있던 것과 달리 / 딕셔너리에 추가를 해야하니까


def proc_factorial(n):
      # 1. 기저 조건: n이 1 이하일 때 1 반환
      if n <= 1:
          return 1


      # 2. 이미 계산한 적이 있는 값이면 메모리에서 즉시 꺼내어 반환
      if n in memo:
          return memo[n]


      # 3. 계산한 적이 없다면 결과를 계산하여 메모리에 기록(저장) 후 반환
      memo[n] = n * proc_factorial(n - 1)
      return memo[n]


# 함수 호출 및 결과 확인
print(proc_factorial(5))  # 출력: 120
print(memo)               # 출력: {2: 2, 3: 6, 4: 24, 5: 120} (저장된 상태)
# Out:
# 120
# {2: 2, 3: 6, 4: 24, 5: 120}

# %% [markdown]
# ### 파이썬 파이토닉(Pythonic) 메모이제이션 데코레이터
# -   @lru_cache 데코레이터 활용
#   - 파이썬 내장 라이브러리를 사용하면 코드 수정 없이 한 줄로 자동 메모리화 가능

# %%
from functools import lru_cache


# maxsize=None은 제한 없이 모든 결과를 메모리에 캐싱하겠다는 의미
@lru_cache(maxsize=None)
def proc_factorial(n):
      if n <= 1:
          return 1
      return n * proc_factorial(n - 1)

# %%
a = [1,2,3]
def proc(a):
    pass

# %%
a = [1,2,3]
print(proc(a))
print(a)
# Out:
# None
# [1, 2, 3]

# %%
t = 3
def proc(t):
    t += 1
    print(f't={t}')

print(proc(4))
print(t)
# Out:
# t=5
# None
# 3
